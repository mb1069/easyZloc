# %%
import glob
from tifffile import imread, imwrite
import matplotlib.pyplot as plt

# %%
dpath = '/home/miguel/Projects/uni/data/smlm_3d/20211126_MQ_controls/A1_647_storm_1/*.tif'
imgs = sorted(glob.glob(dpath))
print(imgs)
# Out:
# ['/home/miguel/Projects/uni/data/smlm_3d/20211126_MQ_controls/A1_647_storm_1/MMStack_Default.ome.tif', '/home/miguel/Projects/uni/data/smlm_3d/20211126_MQ_controls/A1_647_storm_1/MMStack_Default_1.ome.tif', '/home/miguel/Projects/uni/data/smlm_3d/20211126_MQ_controls/A1_647_storm_1/MMStack_Default_2.ome.tif']

# %%
min_x = 431
max_x = min_x + 140
min_y = 451
max_y = min_y + 162

for impath in imgs:
    img = imread(impath)
    print(impath)
    print(img.shape)
#     plt.imshow(img[0])
#     plt.show()
# Out:
# /home/miguel/Projects/uni/data/smlm_3d/20211126_MQ_controls/A1_647_storm_1/MMStack_Default.ome.tif
# (5000, 1000, 1000)
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# OME series: index out of range
# ...
